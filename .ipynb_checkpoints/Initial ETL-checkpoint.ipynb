# %%
import numpy as np
import pandas as pd

# %%
borders = pd.read_csv('GEODATASOURCE-COUNTRY-BORDERS.csv')
data15 = pd.read_csv('2015.csv')
data16 = pd.read_csv('2016.csv')
data17 = pd.read_csv('2017.csv')
data17 = data17.rename(columns = {'Happiness.Score': 'Happiness Score'})

# %%
borders = borders[['country_name', 'country_border_name']]
borders = borders[borders['country_border_name'].notnull()]
data15 = data15[['Country', 'Happiness Score']]
data16 = data16[['Country', 'Happiness Score']]
data17 = data17[['Country', 'Happiness Score']]

# %%
borders = pd.merge(borders, data15, how='inner', left_on='country_border_name', right_on='Country')
borders = borders.drop(['Country'], axis=1)
borders = borders.rename(columns = {'Happiness Score': 'Happiness Score 2015'})
borders = pd.merge(borders, data16, how='inner', left_on='country_border_name', right_on='Country')
borders = borders.drop(['Country'], axis=1)
borders = borders.rename(columns = {'Happiness Score': 'Happiness Score 2016'})
borders = pd.merge(borders, data17, how='inner', left_on='country_border_name', right_on='Country')
borders = borders.drop(['Country'], axis=1)
borders = borders.rename(columns = {'Happiness Score': 'Happiness Score 2017'})
borders
# Out:
#                                 country_name   country_border_name  \
# 0                                    Andorra                France
# 1                                    Belgium                France
# 2                                Switzerland                France
# 3                                    Germany                France
# 4                                      Spain                France
# 5                                      Italy                France
# 6                                 Luxembourg                France
# 7                                     Monaco                France
# 8                                    Andorra                 Spain
# 9                                     France                 Spain
# 10                                 Gibraltar                 Spain
# 11                                   Morocco                 Spain
# 12                                  Portugal                 Spain
# 13                      United Arab Emirates                  Oman
# 14                              Saudi Arabia                  Oman
# 15                                     Yemen                  Oman
# 16                      United Arab Emirates          Saudi Arabia
# 17                                      Iraq          Saudi Arabia
# 18                                    Jordan          Saudi Arabia
# 19                                    Kuwait          Saudi Arabia
# 20                                      Oman          Saudi Arabia
# 21                                     Qatar          Saudi Arabia
# 22                                     Yemen          Saudi Arabia
# 23                               Afghanistan                 China
# 24                                    Bhutan                 China
# 25                                 Hong Kong                 China
# 26                                     India                 China
# 27                                Kyrgyzstan                 China
# 28   Korea (Democratic People's Republic of)                 China
# 29                                Kazakhstan                 China
# ..                                       ...                   ...
# 481                                   Malawi            Mozambique
# 482                                Swaziland            Mozambique
# 483        Tanzania (the United Republic of)            Mozambique
# 484                             South Africa            Mozambique
# 485                                   Zambia            Mozambique
# 486                                 Zimbabwe            Mozambique
# 487                                 Malaysia             Indonesia
# 488                         Papua New Guinea             Indonesia
# 489                              Timor-Leste             Indonesia
# 490                               Mozambique                Malawi
# 491        Tanzania (the United Republic of)                Malawi
# 492                                   Zambia                Malawi
# 493                               Mozambique             Swaziland
# 494                             South Africa             Swaziland
# 495                                  Namibia              Botswana
# 496                             South Africa              Botswana
# 497                                   Zambia              Botswana
# 498                                 Zimbabwe              Botswana
# 499                                Nicaragua            Costa Rica
# 500                                   Panama            Costa Rica
# 501                                   Norway               Finland
# 502                       Russian Federation               Finland
# 503                                   Sweden               Finland
# 504                                     Oman  United Arab Emirates
# 505                             Saudi Arabia  United Arab Emirates
# 506                                     Oman                 Yemen
# 507                             Saudi Arabia                 Yemen
# 508                             Saudi Arabia                 Qatar
# 509                            United States                Canada
# 510                             South Africa               Lesotho
#
#      Happiness Score
# 0              6.575
# 1              6.575
# 2              6.575
# 3              6.575
# 4              6.575
# 5              6.575
# 6              6.575
# 7              6.575
# 8              6.329
# 9              6.329
# 10             6.329
# 11             6.329
# 12             6.329
# 13             6.853
# 14             6.853
# 15             6.853
# 16             6.411
# 17             6.411
# 18             6.411
# 19             6.411
# 20             6.411
# 21             6.411
# 22             6.411
# 23             5.140
# 24             5.140
# 25             5.140
# 26             5.140
# 27             5.140
# 28             5.140
# 29             5.140
# ..               ...
# 481            4.971
# 482            4.971
# 483            4.971
# 484            4.971
# 485            4.971
# 486            4.971
# 487            5.399
# 488            5.399
# 489            5.399
# 490            4.292
# 491            4.292
# 492            4.292
# 493            4.867
# 494            4.867
# 495            4.332
# 496            4.332
# 497            4.332
# 498            4.332
# 499            7.226
# 500            7.226
# 501            7.406
# 502            7.406
# 503            7.406
# 504            6.901
# 505            6.901
# 506            4.077
# 507            4.077
# 508            6.611
# 509            7.427
# 510            4.898
#
# [511 rows x 3 columns]

# %%
merge15 = pd.merge(data15, borders, how='inner', left_on='Country', right_on='country_name')
merge16 = pd.merge(borders, data16, how='inner', left_on='country_name', right_on='Country')
merge17 = pd.merge(borders, data17, how='inner', left_on='country_border_name', right_on='Country')

# %%
# data2018.loc[data2018['Country']=='Iraq']
# df.loc[df['column_name'] == some_value]
merge17
# Out:
#       country_border_name                             country_name  \
# 0                  France                                  Andorra
# 1                  France                                  Belgium
# 2                  France                              Switzerland
# 3                  France                                  Germany
# 4                  France                                    Spain
# 5                  France                                    Italy
# 6                  France                               Luxembourg
# 7                  France                                   Monaco
# 8                   Spain                                  Andorra
# 9                   Spain                                   France
# 10                  Spain                                Gibraltar
# 11                  Spain                                  Morocco
# 12                  Spain                                 Portugal
# 13           Saudi Arabia                     United Arab Emirates
# 14           Saudi Arabia                                     Iraq
# 15           Saudi Arabia                                   Jordan
# 16           Saudi Arabia                                   Kuwait
# 17           Saudi Arabia                                     Oman
# 18           Saudi Arabia                                    Qatar
# 19           Saudi Arabia                                    Yemen
# 20                  China                              Afghanistan
# 21                  China                                   Bhutan
# 22                  China                                Hong Kong
# 23                  China                                    India
# 24                  China                               Kyrgyzstan
# 508  United Arab Emirates            6.648
# 509                 Yemen            3.593
# 510                 Yemen            3.593
# 511                 Qatar            6.375
# 512                Canada            7.316
# 513               Lesotho            3.808
#
# [514 rows x 4 columns]

# %%
merged.loc[merged['country_border_name']=='Mongolia']
# print(data2018.loc[data2018['Country']=='China'])
# print(data2018.loc[data2018['Country']=='Russia'])
# print(data2018.loc[data2018['Country']=='Mongolia'])
# print(data2018.loc[data2018['Country']=='Georgia'])
# Out:
#     country_code        country_name country_border_code country_border_name  \
# 359           CN               China                  MN            Mongolia
# 360           RU  Russian Federation                  MN            Mongolia
#
#       Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 359  Mongolia             100            4.955       5.02168      4.88832
# 360  Mongolia             100            4.955       5.02168      4.88832
#
#      Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 359                  1.027236  1.493011                  0.557783  0.394144
# 360                  1.027236  1.493011                  0.557783  0.394144
#
#      Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 359    0.338464                       0.032902           1.111292
# 360    0.338464                       0.032902           1.111292

# %%
# Out:
#                   Country  Happiness.Score
# 0                  France            6.442
# 1                  France            6.442
# 2                  France            6.442
# 3                  France            6.442
# 4                  France            6.442
# 5                  France            6.442
# 6                  France            6.442
# 7                  France            6.442
# 8                   Spain            6.403
# 9                   Spain            6.403
# 10                  Spain            6.403
# 11                  Spain            6.403
# 12                  Spain            6.403
# 13           Saudi Arabia            6.344
# 14           Saudi Arabia            6.344
# 15           Saudi Arabia            6.344
# 16           Saudi Arabia            6.344
# 17           Saudi Arabia            6.344
# 18           Saudi Arabia            6.344
# 19           Saudi Arabia            6.344
# 20                  China            5.273
# 21                  China            5.273
# 22                  China            5.273
# 23                  China            5.273
# 24                  China            5.273
# 25                  China            5.273
# 26                  China            5.273
# 27                  China            5.273
# 28                  China            5.273
# 29                  China            5.273
# ..                    ...              ...
# 484               Estonia            5.611
# 485               Estonia            5.611
# 486            Mozambique            4.550
# 487            Mozambique            4.550
# 488            Mozambique            4.550
# 489            Mozambique            4.550
# 490            Mozambique            4.550
# 491            Mozambique            4.550
# 492             Indonesia            5.262
# 493             Indonesia            5.262
# 494             Indonesia            5.262
# 495                Malawi            3.970
# 496                Malawi            3.970
# 497                Malawi            3.970
# 498              Botswana            3.766
# 499              Botswana            3.766
# 500              Botswana            3.766
# 501              Botswana            3.766
# 502            Costa Rica            7.079
# 503            Costa Rica            7.079
# 504               Finland            7.469
# 505               Finland            7.469
# 506               Finland            7.469
# 507  United Arab Emirates            6.648
# 508  United Arab Emirates            6.648
# 509                 Yemen            3.593
# 510                 Yemen            3.593
# 511                 Qatar            6.375
# 512                Canada            7.316
# 513               Lesotho            3.808
#
# [514 rows x 2 columns]

# %%
merged = merged.groupby('country_name')['Happiness.Score'].mean()

# %%
merged.loc['Mongolia']
# Out:
# 5.2729997634887695
